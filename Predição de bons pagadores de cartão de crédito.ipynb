# %% [markdown]
# <a href="https://colab.research.google.com/github/viitoriaraujoo/Data-Science-Projects-with-Python/blob/main/Predi%C3%A7%C3%A3o%20de%20bons%20pagadores%20de%20cart%C3%A3o%20de%20cr%C3%A9dito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Predição de bons pagadores de cartão de crédito

# %% [markdown]
# ## 1. Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## 2. Carregamento de Dados

# %%
df= pd.read_excel('https://github.com/TrainingByPackt/Data-Science-Projects-with-Python/raw/master/Data/default_of_credit_card_clients__courseware_version_1_21_19.xls') ## Carregará o arquivo do Excel em um DataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-2796144557.py in <cell line: 0>()
# ----> 1 df= pd.read_excel('https://github.com/TrainingByPackt/Data-Science-Projects-with-Python/raw/master/Data/default_of_credit_card_clients__courseware_version_1_21_19.xls') ## Carregará o arquivo do Excel em um DataFrame
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0         0                           1
# 1      1000      1000         0      2000                           1
# 2      1000      1000      1000      5000                           0
# 3      1200      1100      1069      1000                           0
# 4     10000      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (30000, 25)

# %% [markdown]
# ## 3. Verificando a integridade dos dados
